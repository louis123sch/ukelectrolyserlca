# %% [markdown]
# # Dashboard LCA — orchestration & plotting
#
# This is the single entry point.
#
# 1. Edit settings in [dashboard_config.py](dashboard_config.py).
# 2. (Optionally) run the building-block notebooks:
#    - [tech_lca_foreground.ipynb](tech_lca_foreground.ipynb) — build the foreground DB
#    - [custom_grid.ipynb](custom_grid.ipynb) — custom GB grid LCA
#    - [wind_power.ipynb](wind_power.ipynb) — wind/grid electrolyser LCA
# 3. Run the cells below to load the latest result CSVs and plot them.
#
# No settings live in this notebook — everything is controlled by `dashboard_config.py`.

# %%
# All settings come from dashboard_config.py — the single master dashboard.
# Edit values there once; every notebook picks them up.
from dashboard_config import *
import dashboard_config as cfg
import lca_helpers as H

print_dashboard()
print()
ei, bio, fg_db, method = H.setup_brightway()
# Out:
# /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/bw2calc/__init__.py:54: UserWarning:
# It seems like you have an ARM architecture, but haven't installed scikit-umfpack:
#
#     https://pypi.org/project/scikit-umfpack/
#
# Installing it could give you much faster calculations.
#
#   warnings.warn(UMFPACK_WARNING)
# Master Dashboard
# ----------------
# Project:                 hydrogen-smr
# Foreground DB:           hydrogen foreground
# Build foreground DB:     True
# Run reference LCA:       False
# Run grid scenario LCA:   True
# Grid data source:        carbon_api | notebook: 3.1.custom_grid_carbon_intensity_api.ipynb
# Run wind/grid LCA:       True
# Run price data:          True
# Grid method:             cheap | loss factor: 1.0316426921769999
# Grid output pattern:     custom_grid_lca_carbon_api_*.csv
# Carbon API scope:        regional_auto | cache: True
# Wind/grid method:        cheap
# Selected grid techs:     ['PEM operation']
# Wind/grid mode:          both (blended + switching) | electrolyser(s): ['AE operation']
# Price output dir:        price_outputs
# Elexon provider:         APXMIDP | fallback: N2EXMIDP
# Cost case:               central | wind: central
# (Wind cost details: run 5.prices.ipynb -> price_outputs/wind_annual_costs_per_MW.csv)
#
# Current Brightway project: hydrogen-smr
# Using ecoinvent database: ecoinvent-3.9.1-apos
# Using biosphere database: ecoinvent-3.9.1-biosphere
# Using foreground database: hydrogen foreground
# Using LCIA method: ('ecoinvent-3.9.1', 'IPCC 2021 no LT', 'climate change no LT', 'global warming potential (GWP100) no LT')

# %% [markdown]
# ## Optional: re-run the building-block notebooks in-process

# %%
# Set to True to re-execute each child notebook (the dashboard settings will
# be used automatically because every notebook imports dashboard_config).
RUN_FOREGROUND_NOTEBOOK = True
RUN_GRID_NOTEBOOK       = True
RUN_WIND_NOTEBOOK       = True

# GRID_NOTEBOOK is derived from GRID_DATA_SOURCE in dashboard_config.py:
#   GRID_DATA_SOURCE = "csv"        -> 3.custom_grid.ipynb
#   GRID_DATA_SOURCE = "carbon_api" -> 3.1.custom_grid_carbon_intensity_api.ipynb
from IPython import get_ipython
_ip = get_ipython()

if RUN_FOREGROUND_NOTEBOOK:
    _ip.run_line_magic("run", '"2.tech_lca_foreground.ipynb"')
if RUN_GRID_NOTEBOOK:
    print("Running selected grid notebook:", getattr(cfg, "GRID_NOTEBOOK", "3.custom_grid.ipynb"))
    _ip.run_line_magic("run", f'"{getattr(cfg, "GRID_NOTEBOOK", "3.custom_grid.ipynb")}"')
if RUN_WIND_NOTEBOOK:
    _ip.run_line_magic("run", '"4.wind_power.ipynb"')
# Out:
# Master Dashboard
# ----------------
# Project:                 hydrogen-smr
# Foreground DB:           hydrogen foreground
# Build foreground DB:     True
# Run reference LCA:       False
# Run grid scenario LCA:   True
# Grid data source:        carbon_api | notebook: 3.1.custom_grid_carbon_intensity_api.ipynb
# Run wind/grid LCA:       True
# Run price data:          True
# Grid method:             cheap | loss factor: 1.0316426921769999
# Grid output pattern:     custom_grid_lca_carbon_api_*.csv
# Carbon API scope:        regional_auto | cache: True
# Wind/grid method:        cheap
# Selected grid techs:     ['PEM operation']
# Wind/grid mode:          both (blended + switching) | electrolyser(s): ['AE operation']
# Price output dir:        price_outputs
# Elexon provider:         APXMIDP | fallback: N2EXMIDP
# Cost case:               central | wind: central
# (Wind cost details: run 5.prices.ipynb -> price_outputs/wind_annual_costs_per_MW.csv)
#
# Current Brightway project: hydrogen-smr
# Using ecoinvent database: ecoinvent-3.9.1-apos
# Using biosphere database: ecoinvent-3.9.1-biosphere
# Using foreground database: hydrogen foreground
# Using LCIA method: ('ecoinvent-3.9.1', 'IPCC 2021 no LT', 'climate change no LT', 'global warming potential (GWP100) no LT')
#
# ==========================================================================================
# electricity : market for electricity high voltage GB
#     0 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: BE
#     1 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: NL
#     2 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: FR
#     3 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: IE
#     4 | name: electricity, high voltage, import from IE | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     5 | name: electricity, high voltage, import from NL | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     6 | name: electricity, high voltage, import from FR | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     7 | name: electricity, high voltage, import from BE | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     8 | name: market for electricity, low voltage | ref: electricity, low voltage | unit: kilowatt hour | loc: GB
#     9 | name: market for electricity, medium voltage | ref: electricity, medium voltage | unit: kilowatt hour | loc: GB
#    10 | name: market for electricity, high voltage | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#    11 | name: electricity, high voltage, residual mix | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#    12 | name: electricity, low voltage, residual mix | ref: electricity, low voltage | unit: kilowatt hour | loc: GB
#    13 | name: electricity, medium voltage, residual mix | ref: electricity, medium voltage | unit: kilowatt hour | loc: GB
#    14 | name: electricity production, natural gas, aluminium industry | ref: electricity, high voltage, aluminium industry | unit: kilowatt hour | loc: IAI Area, EU27 & EFTA
#    15 | name: electricity production, oil, aluminium industry | ref: electricity, high voltage, aluminium industry | unit: kilowatt hour | loc: IAI Area, EU27 & EFTA
#    16 | name: electricity production, oil | ref: electricity, high voltage | unit: kilowatt hour | loc: PL
#    17 | name: electricity production, oil | ref: electricity, high voltage | unit: kilowatt hour | loc: LU
#    18 | name: electricity production, hard coal | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#
#   → Selected [10]: market for electricity, high voltage | GB
#
# ==========================================================================================
# gas : market for natural gas high pressure GB
#     0 | name: natural gas pressure reduction, from high to low pressure | ref: natural gas, low pressure | unit: cubic meter | loc: GB
#     1 | name: market for natural gas, high pressure | ref: natural gas, high pressure | unit: cubic meter | loc: GB
#     2 | name: market for natural gas, low pressure | ref: natural gas, low pressure | unit: cubic meter | loc: GB
#     3 | name: transport, pipeline, onshore, long distance, natural gas | ref: transport, pipeline, onshore, long distance, natural gas | unit: ton kilometer | loc: GB
#     4 | name: transport, pipeline, offshore, long distance, natural gas | ref: transport, pipeline, offshore, long distance, natural gas | unit: ton kilometer | loc: GB
#
#   → Selected [1]: market for natural gas, high pressure | GB
#
# ==========================================================================================
# tap_water : market for tap water Europe without Switzerland
#     0 | name: market for tap water | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     1 | name: tap water production, underground water without treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     2 | name: tap water production, underground water with disinfection | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     3 | name: tap water production, underground water with chemical treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     4 | name: tap water production, direct filtration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     5 | name: tap water production, microstrainer treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     6 | name: tap water production, conventional treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     7 | name: tap water production, conventional with biological treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     8 | name: tap water production, ultrafiltration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#
#   → Selected [0]: market for tap water | Europe without Switzerland
#
# ==========================================================================================
# concrete : market for concrete normal RoW
#     0 | name: concrete, all types to generic market for concrete, normal strength | ref: concrete, normal strength | unit: cubic meter | loc: RoW
#     1 | name: market for concrete, normal strength | ref: concrete, normal strength | unit: cubic meter | loc: RoW
#     2 | name: concrete, all types to generic market for concrete, medium strength | ref: concrete, medium strength | unit: cubic meter | loc: RoW
#
#   → Selected [0]: concrete, all types to generic market for concrete, normal strength | RoW
#
# ==========================================================================================
# steel : market for steel unalloyed GLO
#     0 | name: market for steel, unalloyed | ref: steel, unalloyed | unit: kilogram | loc: GLO
#     1 | name: market for power sawing, with catalytic converter | ref: power sawing, with catalytic converter | unit: hour | loc: GLO
#     2 | name: market for assembly of generator and motor, auxilliaries and energy use, for mini CHP plant | ref: assembly of generator and motor, auxilliaries and energy use, for mini CHP plant | unit: unit | loc: GLO
#
#   → Selected [0]: market for steel, unalloyed | GLO
#
# ==========================================================================================
# aluminium : aluminium primary cast alloy slab continuous casting GLO
#     0 | name: market for aluminium, primary, cast alloy slab from continuous casting | ref: aluminium, primary, cast alloy slab from continuous casting | unit: kilogram | loc: GLO
#
#   → Selected [0]: market for aluminium, primary, cast alloy slab from continuous casting | GLO
#
# ==========================================================================================
# cast_iron : market for cast iron GLO
#     0 | name: market for cast iron | ref: cast iron | unit: kilogram | loc: GLO
#     1 | name: market for cast iron removed by milling, average | ref: cast iron removed by milling, average | unit: kilogram | loc: GLO
#     2 | name: market for cast iron removed by milling, large parts | ref: cast iron removed by milling, large parts | unit: kilogram | loc: GLO
#     3 | name: market for cast iron removed by milling, small parts | ref: cast iron removed by milling, small parts | unit: kilogram | loc: GLO
#     4 | name: market for cast iron removed by drilling, conventional | ref: cast iron removed by drilling, conventional | unit: kilogram | loc: GLO
#     5 | name: market for cast iron removed by turning, average, conventional | ref: cast iron removed by turning, average, conventional | unit: kilogram | loc: GLO
#     6 | name: market for cast iron removed by milling, dressing | ref: cast iron removed by milling, dressing | unit: kilogram | loc: GLO
#     7 | name: market for cast iron removed by turning, average, computer numerical controlled | ref: cast iron removed by turning, average, computer numerical controlled | unit: kilogram | loc: GLO
#     8 | name: market for cast iron removed by drilling, computer numerical controlled | ref: cast iron removed by drilling, computer numerical controlled | unit: kilogram | loc: GLO
#     9 | name: market for cast iron removed by turning, primarily roughing, conventional | ref: cast iron removed by turning, primarily roughing, conventional | unit: kilogram | loc: GLO
#    10 | name: market for cast iron removed by turning, primarily roughing, computer numerical controlled | ref: cast iron removed by turning, primarily roughing, computer numerical controlled | unit: kilogram | loc: GLO
#    11 | name: market for cast iron removed by turning, primarily dressing, conventional | ref: cast iron removed by turning, primarily dressing, conventional | unit: kilogram | loc: GLO
#    12 | name: market for cast iron removed by turning, primarily dressing, computer numerical controlled | ref: cast iron removed by turning, primarily dressing, computer numerical controlled | unit: kilogram | loc: GLO
#    13 | name: market for steel, unalloyed | ref: steel, unalloyed | unit: kilogram | loc: GLO
#    14 | name: market for steel, low-alloyed | ref: steel, low-alloyed | unit: kilogram | loc: GLO
#    15 | name: market for steel, chromium steel 18/8 | ref: steel, chromium steel 18/8 | unit: kilogram | loc: GLO
#    16 | name: market for industrial furnace, 1MW, oil | ref: industrial furnace, 1MW, oil | unit: unit | loc: GLO
#    17 | name: market for nuclear fuel factory | ref: nuclear fuel factory | unit: unit | loc: GLO
#    18 | name: market for pipeline, natural gas, high pressure distribution network | ref: pipeline, natural gas, high pressure distribution network | unit: kilometer | loc: GLO
#    19 | name: primary zinc production from concentrate | ref: iron scrap, unsorted | unit: kilogram | loc: CA-QC
#    20 | name: 2,4-dichlorophenol production | ref: 2,4-dichlorophenol | unit: kilogram | loc: RoW
#    21 | name: primary zinc production from concentrate | ref: zinc | unit: kilogram | loc: CA-QC
#    22 | name: primary zinc production from concentrate | ref: sulfuric acid | unit: kilogram | loc: CA-QC
#    23 | name: primary zinc production from concentrate | ref: sulfur dioxide, liquid | unit: kilogram | loc: CA-QC
#    24 | name: primary zinc production from concentrate | ref: cadmium sludge from zinc electrolysis | unit: kilogram | loc: CA-QC
#
#   → Selected [0]: market for cast iron | GLO
#
# ==========================================================================================
# gas_turbine : gas turbine 10MW electrical GLO
#     0 | name: market for gas turbine, 10MW electrical | ref: gas turbine, 10MW electrical | unit: unit | loc: GLO
#
#   → Selected [0]: market for gas turbine, 10MW electrical | GLO
#
# ==========================================================================================
# wastewater : market for wastewater average Europe without Switzerland
#     0 | name: market for wastewater, average | ref: wastewater, average | unit: cubic meter | loc: Europe without Switzerland
#     1 | name: treatment of wastewater, average, wastewater treatment | ref: wastewater, average | unit: cubic meter | loc: Europe without Switzerland
#     2 | name: treatment of wastewater, average, wastewater treatment | ref: iron scrap, sorted, pressed | unit: kilogram | loc: Europe without Switzerland
#     3 | name: treatment of wastewater, average, wastewater treatment | ref: heat, central or small-scale, other than natural gas | unit: megajoule | loc: Europe without Switzerland
#     4 | name: treatment of wastewater from pig iron production, wastewater treatment | ref: wastewater from pig iron production | unit: cubic meter | loc: Europe without Switzerland
#     5 | name: treatment of wastewater from pig iron production, wastewater treatment | ref: iron scrap, sorted, pressed | unit: kilogram | loc: Europe without Switzerland
#     6 | name: tap water production, underground water without treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     7 | name: tap water production, underground water with chemical treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     8 | name: tap water production, direct filtration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     9 | name: tap water production, conventional treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#    10 | name: tap water production, microstrainer treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#    11 | name: tap water production, conventional with biological treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#    12 | name: tap water production, ultrafiltration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#
#   → Selected [0]: market for wastewater, average | Europe without Switzerland
#
# ==========================================================================================
# electricity : market for electricity high voltage GB
#     0 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: BE
#     1 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: NL
#     2 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: FR
#     3 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: IE
#     4 | name: electricity, high voltage, import from IE | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     5 | name: electricity, high voltage, import from NL | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     6 | name: electricity, high voltage, import from FR | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     7 | name: electricity, high voltage, import from BE | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     8 | name: market for electricity, low voltage | ref: electricity, low voltage | unit: kilowatt hour | loc: GB
#     9 | name: market for electricity, medium voltage | ref: electricity, medium voltage | unit: kilowatt hour | loc: GB
#    10 | name: market for electricity, high voltage | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#    11 | name: electricity, high voltage, residual mix | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#    12 | name: electricity, low voltage, residual mix | ref: electricity, low voltage | unit: kilowatt hour | loc: GB
#    13 | name: electricity, medium voltage, residual mix | ref: electricity, medium voltage | unit: kilowatt hour | loc: GB
#    14 | name: electricity production, natural gas, aluminium industry | ref: electricity, high voltage, aluminium industry | unit: kilowatt hour | loc: IAI Area, EU27 & EFTA
#    15 | name: electricity production, oil, aluminium industry | ref: electricity, high voltage, aluminium industry | unit: kilowatt hour | loc: IAI Area, EU27 & EFTA
#    16 | name: electricity production, oil | ref: electricity, high voltage | unit: kilowatt hour | loc: PL
#    17 | name: electricity production, oil | ref: electricity, high voltage | unit: kilowatt hour | loc: LU
#    18 | name: electricity production, hard coal | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#
#   → Selected [10]: market for electricity, high voltage | GB
#
# ==========================================================================================
# gas : market for natural gas high pressure GB
#     0 | name: natural gas pressure reduction, from high to low pressure | ref: natural gas, low pressure | unit: cubic meter | loc: GB
#     1 | name: market for natural gas, high pressure | ref: natural gas, high pressure | unit: cubic meter | loc: GB
#     2 | name: market for natural gas, low pressure | ref: natural gas, low pressure | unit: cubic meter | loc: GB
#     3 | name: transport, pipeline, onshore, long distance, natural gas | ref: transport, pipeline, onshore, long distance, natural gas | unit: ton kilometer | loc: GB
#     4 | name: transport, pipeline, offshore, long distance, natural gas | ref: transport, pipeline, offshore, long distance, natural gas | unit: ton kilometer | loc: GB
#
#   → Selected [1]: market for natural gas, high pressure | GB
#
# ==========================================================================================
# tap_water : market for tap water Europe without Switzerland
#     0 | name: market for tap water | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     1 | name: tap water production, underground water without treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     2 | name: tap water production, underground water with disinfection | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     3 | name: tap water production, underground water with chemical treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     4 | name: tap water production, direct filtration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     5 | name: tap water production, microstrainer treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     6 | name: tap water production, conventional treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     7 | name: tap water production, conventional with biological treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     8 | name: tap water production, ultrafiltration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#
#   → Selected [0]: market for tap water | Europe without Switzerland
#
# ==========================================================================================
# concrete : market for concrete normal RoW
#     0 | name: concrete, all types to generic market for concrete, normal strength | ref: concrete, normal strength | unit: cubic meter | loc: RoW
#     1 | name: market for concrete, normal strength | ref: concrete, normal strength | unit: cubic meter | loc: RoW
#     2 | name: concrete, all types to generic market for concrete, medium strength | ref: concrete, medium strength | unit: cubic meter | loc: RoW
#
#   → Selected [0]: concrete, all types to generic market for concrete, normal strength | RoW
#
# ==========================================================================================
# steel : market for steel unalloyed GLO
#     0 | name: market for steel, unalloyed | ref: steel, unalloyed | unit: kilogram | loc: GLO
#     1 | name: market for power sawing, with catalytic converter | ref: power sawing, with catalytic converter | unit: hour | loc: GLO
#     2 | name: market for assembly of generator and motor, auxilliaries and energy use, for mini CHP plant | ref: assembly of generator and motor, auxilliaries and energy use, for mini CHP plant | unit: unit | loc: GLO
#
#   → Selected [0]: market for steel, unalloyed | GLO
#
# ==========================================================================================
# aluminium : aluminium primary cast alloy slab continuous casting GLO
#     0 | name: market for aluminium, primary, cast alloy slab from continuous casting | ref: aluminium, primary, cast alloy slab from continuous casting | unit: kilogram | loc: GLO
#
#   → Selected [0]: market for aluminium, primary, cast alloy slab from continuous casting | GLO
#
# ==========================================================================================
# cast_iron : market for cast iron GLO
#     0 | name: market for cast iron | ref: cast iron | unit: kilogram | loc: GLO
#     1 | name: market for cast iron removed by milling, average | ref: cast iron removed by milling, average | unit: kilogram | loc: GLO
#     2 | name: market for cast iron removed by milling, large parts | ref: cast iron removed by milling, large parts | unit: kilogram | loc: GLO
#     3 | name: market for cast iron removed by milling, small parts | ref: cast iron removed by milling, small parts | unit: kilogram | loc: GLO
#     4 | name: market for cast iron removed by drilling, conventional | ref: cast iron removed by drilling, conventional | unit: kilogram | loc: GLO
#     5 | name: market for cast iron removed by turning, average, conventional | ref: cast iron removed by turning, average, conventional | unit: kilogram | loc: GLO
#     6 | name: market for cast iron removed by milling, dressing | ref: cast iron removed by milling, dressing | unit: kilogram | loc: GLO
#     7 | name: market for cast iron removed by turning, average, computer numerical controlled | ref: cast iron removed by turning, average, computer numerical controlled | unit: kilogram | loc: GLO
#     8 | name: market for cast iron removed by drilling, computer numerical controlled | ref: cast iron removed by drilling, computer numerical controlled | unit: kilogram | loc: GLO
#     9 | name: market for cast iron removed by turning, primarily roughing, conventional | ref: cast iron removed by turning, primarily roughing, conventional | unit: kilogram | loc: GLO
#    10 | name: market for cast iron removed by turning, primarily roughing, computer numerical controlled | ref: cast iron removed by turning, primarily roughing, computer numerical controlled | unit: kilogram | loc: GLO
#    11 | name: market for cast iron removed by turning, primarily dressing, conventional | ref: cast iron removed by turning, primarily dressing, conventional | unit: kilogram | loc: GLO
#    12 | name: market for cast iron removed by turning, primarily dressing, computer numerical controlled | ref: cast iron removed by turning, primarily dressing, computer numerical controlled | unit: kilogram | loc: GLO
#    13 | name: market for steel, unalloyed | ref: steel, unalloyed | unit: kilogram | loc: GLO
#    14 | name: market for steel, low-alloyed | ref: steel, low-alloyed | unit: kilogram | loc: GLO
#    15 | name: market for steel, chromium steel 18/8 | ref: steel, chromium steel 18/8 | unit: kilogram | loc: GLO
#    16 | name: market for industrial furnace, 1MW, oil | ref: industrial furnace, 1MW, oil | unit: unit | loc: GLO
#    17 | name: market for nuclear fuel factory | ref: nuclear fuel factory | unit: unit | loc: GLO
#    18 | name: market for pipeline, natural gas, high pressure distribution network | ref: pipeline, natural gas, high pressure distribution network | unit: kilometer | loc: GLO
#    19 | name: primary zinc production from concentrate | ref: iron scrap, unsorted | unit: kilogram | loc: CA-QC
#    20 | name: 2,4-dichlorophenol production | ref: 2,4-dichlorophenol | unit: kilogram | loc: RoW
#    21 | name: primary zinc production from concentrate | ref: zinc | unit: kilogram | loc: CA-QC
#    22 | name: primary zinc production from concentrate | ref: sulfuric acid | unit: kilogram | loc: CA-QC
#    23 | name: primary zinc production from concentrate | ref: sulfur dioxide, liquid | unit: kilogram | loc: CA-QC
#    24 | name: primary zinc production from concentrate | ref: cadmium sludge from zinc electrolysis | unit: kilogram | loc: CA-QC
#
#   → Selected [0]: market for cast iron | GLO
#
# ==========================================================================================
# gas_turbine : gas turbine 10MW electrical GLO
#     0 | name: market for gas turbine, 10MW electrical | ref: gas turbine, 10MW electrical | unit: unit | loc: GLO
#
#   → Selected [0]: market for gas turbine, 10MW electrical | GLO
#
# ==========================================================================================
# wastewater : market for wastewater average Europe without Switzerland
#     0 | name: market for wastewater, average | ref: wastewater, average | unit: cubic meter | loc: Europe without Switzerland
#     1 | name: treatment of wastewater, average, wastewater treatment | ref: wastewater, average | unit: cubic meter | loc: Europe without Switzerland
#     2 | name: treatment of wastewater, average, wastewater treatment | ref: iron scrap, sorted, pressed | unit: kilogram | loc: Europe without Switzerland
#     3 | name: treatment of wastewater, average, wastewater treatment | ref: heat, central or small-scale, other than natural gas | unit: megajoule | loc: Europe without Switzerland
#     4 | name: treatment of wastewater from pig iron production, wastewater treatment | ref: wastewater from pig iron production | unit: cubic meter | loc: Europe without Switzerland
#     5 | name: treatment of wastewater from pig iron production, wastewater treatment | ref: iron scrap, sorted, pressed | unit: kilogram | loc: Europe without Switzerland
#     6 | name: tap water production, underground water without treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     7 | name: tap water production, underground water with chemical treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     8 | name: tap water production, direct filtration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#     9 | name: tap water production, conventional treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#    10 | name: tap water production, microstrainer treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#    11 | name: tap water production, conventional with biological treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#    12 | name: tap water production, ultrafiltration treatment | ref: tap water | unit: kilogram | loc: Europe without Switzerland
#
#   → Selected [0]: market for wastewater, average | Europe without Switzerland
#
# ==========================================================================================
# ccs_pipeline : pipeline natural gas long distance low capacity onshore GLO
#     0 | name: market for pipeline, natural gas, long distance, low capacity, onshore | ref: pipeline, natural gas, long distance, low capacity, onshore | unit: kilometer | loc: GLO
#     1 | name: pipeline construction, natural gas, long distance, low capacity, onshore | ref: pipeline, natural gas, long distance, low capacity, onshore | unit: kilometer | loc: GLO
#     2 | name: pipeline construction, natural gas, long distance, high capacity, onshore | ref: pipeline, natural gas, long distance, high capacity, onshore | unit: kilometer | loc: GLO
#
#   → Selected [0]: market for pipeline, natural gas, long distance, low capacity, onshore | GLO
#
# ==========================================================================================
# ccs_well : onshore well oil gas GLO
#     0 | name: onshore well production, oil/gas | ref: onshore well, oil/gas | unit: meter | loc: GLO
#     1 | name: market for onshore well, oil/gas | ref: onshore well, oil/gas | unit: meter | loc: GLO
#     2 | name: onshore natural gas field infrastructure production | ref: onshore natural gas field infrastructure | unit: unit | loc: GLO
#     3 | name: onshore petroleum field infrastructure construction | ref: onshore petroleum field infrastructure | unit: unit | loc: GLO
#     4 | name: deep well drilling, for geothermal power, onshore, 6000m | ref: deep well, for geothermal power, onshore, 6000m | unit: meter | loc: GLO
#     5 | name: market for deep well, for geothermal power, onshore, 6000m | ref: deep well, for geothermal power, onshore, 6000m | unit: meter | loc: GLO
#     6 | name: deep well drilling, for deep geothermal power | ref: deep well, drilled, for geothermal power | unit: meter | loc: RoW
#     7 | name: natural gas production, unprocessed, at extraction | ref: natural gas, unprocessed, at extraction | unit: cubic meter | loc: GLO
#
#   → Selected [1]: market for onshore well, oil/gas | GLO
#
# ==========================================================================================
# ccs_diesel : market group for diesel RER
#     0 | name: market group for diesel | ref: diesel | unit: kilogram | loc: RER
#     1 | name: market group for diesel, low-sulfur | ref: diesel, low-sulfur | unit: kilogram | loc: RER
#     2 | name: market for diesel | ref: diesel | unit: kilogram | loc: BR
#     3 | name: market for lorry, 40 metric ton | ref: lorry, 40 metric ton | unit: unit | loc: RER
#     4 | name: market for lorry, 28 metric ton | ref: lorry, 28 metric ton | unit: unit | loc: RER
#     5 | name: market for lorry, 16 metric ton | ref: lorry, 16 metric ton | unit: unit | loc: RER
#     6 | name: market for transport, passenger car | ref: transport, passenger car | unit: kilometer | loc: RER
#     7 | name: market for transport, freight, inland waterways, barge | ref: transport, freight, inland waterways, barge | unit: ton kilometer | loc: RER
#     8 | name: market for transport, freight, inland waterways, barge tanker | ref: transport, freight, inland waterways, barge tanker | unit: ton kilometer | loc: RER
#     9 | name: market for transport, passenger car, EURO 5 | ref: transport, passenger car, EURO 5 | unit: kilometer | loc: RER
#    10 | name: market for transport, passenger car, EURO 3 | ref: transport, passenger car, EURO 3 | unit: kilometer | loc: RER
#    11 | name: market for transport, passenger car, EURO 4 | ref: transport, passenger car, EURO 4 | unit: kilometer | loc: RER
#    12 | name: market for transport, freight, lorry >32 metric ton, EURO6 | ref: transport, freight, lorry >32 metric ton, EURO6 | unit: ton kilometer | loc: RER
#    13 | name: market for transport, freight, lorry >32 metric ton, EURO4 | ref: transport, freight, lorry >32 metric ton, EURO4 | unit: ton kilometer | loc: RER
#    14 | name: market for transport, freight, lorry >32 metric ton, EURO3 | ref: transport, freight, lorry >32 metric ton, EURO3 | unit: ton kilometer | loc: RER
#    15 | name: market for transport, freight, lorry >32 metric ton, EURO5 | ref: transport, freight, lorry >32 metric ton, EURO5 | unit: ton kilometer | loc: RER
#    16 | name: market for transport, freight, lorry 16-32 metric ton, EURO3 | ref: transport, freight, lorry 16-32 metric ton, EURO3 | unit: ton kilometer | loc: RER
#    17 | name: market for transport, freight, lorry 16-32 metric ton, EURO4 | ref: transport, freight, lorry 16-32 metric ton, EURO4 | unit: ton kilometer | loc: RER
#    18 | name: market for transport, freight, lorry 16-32 metric ton, EURO5 | ref: transport, freight, lorry 16-32 metric ton, EURO5 | unit: ton kilometer | loc: RER
#    19 | name: market for transport, freight, lorry 16-32 metric ton, EURO6 | ref: transport, freight, lorry 16-32 metric ton, EURO6 | unit: ton kilometer | loc: RER
#    20 | name: market for transport, freight, lorry 7.5-16 metric ton, EURO3 | ref: transport, freight, lorry 7.5-16 metric ton, EURO3 | unit: ton kilometer | loc: RER
#    21 | name: market for transport, freight, lorry 7.5-16 metric ton, EURO4 | ref: transport, freight, lorry 7.5-16 metric ton, EURO4 | unit: ton kilometer | loc: RER
#    22 | name: market for transport, freight, lorry 7.5-16 metric ton, EURO6 | ref: transport, freight, lorry 7.5-16 metric ton, EURO6 | unit: ton kilometer | loc: RER
#    23 | name: market for transport, freight, lorry 7.5-16 metric ton, EURO5 | ref: transport, freight, lorry 7.5-16 metric ton, EURO5 | unit: ton kilometer | loc: RER
#    24 | name: market for transport, freight, lorry 3.5-7.5 metric ton, EURO4 | ref: transport, freight, lorry 3.5-7.5 metric ton, EURO4 | unit: ton kilometer | loc: RER
#
#   → Selected [0]: market group for diesel | RER
#
# ==========================================================================================
# electricity : market for electricity high voltage GB
#     0 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: BE
#     1 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: NL
#     2 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: FR
#     3 | name: electricity, high voltage, import from GB | ref: electricity, high voltage | unit: kilowatt hour | loc: IE
#     4 | name: electricity, high voltage, import from IE | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     5 | name: electricity, high voltage, import from NL | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     6 | name: electricity, high voltage, import from FR | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     7 | name: electricity, high voltage, import from BE | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     8 | name: market for electricity, low voltage | ref: electricity, low voltage | unit: kilowatt hour | loc: GB
#     9 | name: market for electricity, medium voltage | ref: electricity, medium voltage | unit: kilowatt hour | loc: GB
#    10 | name: market for electricity, high voltage | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#    11 | name: electricity, high voltage, residual mix | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#    12 | name: electricity, low voltage, residual mix | ref: electricity, low voltage | unit: kilowatt hour | loc: GB
#    13 | name: electricity, medium voltage, residual mix | ref: electricity, medium voltage | unit: kilowatt hour | loc: GB
#    14 | name: electricity production, natural gas, aluminium industry | ref: electricity, high voltage, aluminium industry | unit: kilowatt hour | loc: IAI Area, EU27 & EFTA
#    15 | name: electricity production, oil, aluminium industry | ref: electricity, high voltage, aluminium industry | unit: kilowatt hour | loc: IAI Area, EU27 & EFTA
#    16 | name: electricity production, oil | ref: electricity, high voltage | unit: kilowatt hour | loc: PL
#    17 | name: electricity production, oil | ref: electricity, high voltage | unit: kilowatt hour | loc: LU
#    18 | name: electricity production, hard coal | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#
#   → Selected [10]: market for electricity, high voltage | GB
#
# ==========================================================================================
# gas : market for natural gas high pressure GB
#     0 | name: natural gas pressure reduction, from high to low pressure | ref: natural gas, low pressure | unit: cubic meter | loc: GB
#     1 | name: market for natural gas, high pressure | ref: natural gas, high pressure | unit: cubic meter | loc: GB
#     2 | name: market for natural gas, low pressure | ref: natural gas, low pressure | unit: cubic meter | loc: GB
#     3 | name: transport, pipeline, onshore, long distance, natural gas | ref: transport, pipeline, onshore, long distance, natural gas | unit: ton kilometer | loc: GB
#     4 | name: transport, pipeline, offshore, long distance, natural gas | ref: transport, pipeline, offshore, long distance, natural gas | unit: ton kilometer | loc: GB
#
#   → Selected [1]: market for natural gas, high pressure | GB
#
# ==========================================================================================
# high_alloyed_steel : Market for steel, chromium steel 18/8 GLO
#     0 | name: market for steel, chromium steel 18/8, hot rolled | ref: steel, chromium steel 18/8, hot rolled | unit: kilogram | loc: GLO
#     1 | name: market for steel, chromium steel 18/8 | ref: steel, chromium steel 18/8 | unit: kilogram | loc: GLO
#
#   → Selected [1]: market for steel, chromium steel 18/8 | GLO
#
# ==========================================================================================
# low_alloyed_steel : Market for steel, low-alloyed GLO
#     0 | name: market for steel, low-alloyed, hot rolled | ref: steel, low-alloyed, hot rolled | unit: kilogram | loc: GLO
#     1 | name: market for steel, low-alloyed | ref: steel, low-alloyed | unit: kilogram | loc: GLO
#     2 | name: market for sheet rolling, steel | ref: sheet rolling, steel | unit: kilogram | loc: GLO
#
#   → Selected [1]: market for steel, low-alloyed | GLO
#
# ==========================================================================================
# palladium : Market for palladium GLO
#     0 | name: market for palladium | ref: palladium | unit: kilogram | loc: GLO
#     1 | name: palladium to generic market for metal catalyst for catalytic converter | ref: metal catalyst for catalytic converter | unit: kilogram | loc: GLO
#     2 | name: market for metal catalyst for catalytic converter | ref: metal catalyst for catalytic converter | unit: kilogram | loc: GLO
#     3 | name: platinum to generic market for metal catalyst for catalytic converter | ref: metal catalyst for catalytic converter | unit: kilogram | loc: GLO
#     4 | name: rhodium to generic market for metal catalyst for catalytic converter | ref: metal catalyst for catalytic converter | unit: kilogram | loc: GLO
#     5 | name: market for catalytic converter, three-way, 19.1l | ref: catalytic converter, three-way, 19.1l | unit: unit | loc: GLO
#     6 | name: market for catalytic converter, three-way, mini CHP plant | ref: catalytic converter, three-way, mini CHP plant | unit: unit | loc: GLO
#     7 | name: market for catalytic converter, oxidation, 20 litre | ref: catalytic converter, oxidation, 20 litre | unit: unit | loc: GLO
#
#   → Selected [1]: palladium to generic market for metal catalyst for catalytic converter | GLO
#
# ==========================================================================================
# copper : Cathode Market for copper GLO
#     0 | name: market for copper, cathode | ref: copper, cathode | unit: kilogram | loc: GLO
#     1 | name: market for electrolyte, copper-rich | ref: electrolyte, copper-rich | unit: kilogram | loc: GLO
#     2 | name: smelting and refining of nickel concentrate, 16% Ni | ref: copper concentrate, sulfide ore | unit: kilogram | loc: GLO
#     3 | name: smelting and refining of nickel concentrate, 16% Ni | ref: sulfuric acid | unit: kilogram | loc: GLO
#     4 | name: smelting and refining of nickel concentrate, 16% Ni | ref: ammonium sulfate | unit: kilogram | loc: GLO
#     5 | name: smelting and refining of nickel concentrate, 16% Ni | ref: nickel, class 1 | unit: kilogram | loc: GLO
#     6 | name: smelting and refining of nickel concentrate, 16% Ni | ref: steam, in chemical industry | unit: kilogram | loc: GLO
#
#   → Selected [0]: market for copper, cathode | GLO
#
# ==========================================================================================
# silica_sand : Market for silica sand GLO
#     0 | name: market for silica sand | ref: silica sand | unit: kilogram | loc: GLO
#     1 | name: market for sand-lime brick | ref: sand-lime brick | unit: kilogram | loc: GLO
#     2 | name: foam glass production | ref: foam glass | unit: kilogram | loc: GLO
#     3 | name: foam glass production, without cullet | ref: foam glass | unit: kilogram | loc: GLO
#     4 | name: foam glass production, without cullet, electricity from renewable energy products | ref: foam glass, electricity from renewable energy products | unit: kilogram | loc: GLO
#     5 | name: clinker production | ref: clinker | unit: kilogram | loc: ZA
#
#   → Selected [0]: market for silica sand | GLO
#
# ==========================================================================================
# tin : Market for tin GLO
#     0 | name: market for tin | ref: tin | unit: kilogram | loc: GLO
#     1 | name: market for tin concentrate | ref: tin concentrate | unit: kilogram | loc: GLO
#     2 | name: market for tin dioxide | ref: tin dioxide | unit: kilogram | loc: GLO
#     3 | name: market for tin plated chromium steel sheet, 2 mm | ref: tin plated chromium steel sheet, 2 mm | unit: square meter | loc: GLO
#     4 | name: market for tin plating, pieces | ref: tin plating, pieces | unit: square meter | loc: GLO
#     5 | name: market for tin slag | ref: tin slag | unit: kilogram | loc: GLO
#     6 | name: market for sputtering target, sintered, indium tin oxide | ref: sputtering target, sintered, indium tin oxide | unit: kilogram | loc: GLO
#     7 | name: market for sputtering, indium tin oxide, for liquid crystal display | ref: sputtering, indium tin oxide, for liquid crystal display | unit: cubic meter | loc: GLO
#     8 | name: tungsten mine operation and beneficiation | ref: tungsten concentrate | unit: kilogram | loc: RoW
#     9 | name: primary lead production from concentrate | ref: lead | unit: kilogram | loc: GLO
#    10 | name: primary lead production from concentrate | ref: sulfuric acid | unit: kilogram | loc: GLO
#
#   → Selected [0]: market for tin | GLO
#
# ==========================================================================================
# silicon_carbide : Market for silicon carbide GLO
#     0 | name: market for silicon carbide | ref: silicon carbide | unit: kilogram | loc: GLO
#
#   → Selected [0]: market for silicon carbide | GLO
#
# ==========================================================================================
# polyethylene_hd : polyethylene production high density granulate
#     0 | name: polyethylene, high density, granulate, recycled to generic market for high density PE granulate | ref: polyethylene, high density, granulate | unit: kilogram | loc: RoW
#     1 | name: polyethylene production, high density, granulate, recycled | ref: polyethylene, high density, granulate, recycled | unit: kilogram | loc: RoW
#     2 | name: polyethylene production, high density, granulate, recycled | ref: polyethylene, high density, granulate, recycled | unit: kilogram | loc: CH
#     3 | name: polyethylene production, high density, granulate, recycled | ref: polyethylene, high density, granulate, recycled | unit: kilogram | loc: US
#     4 | name: polyethylene production, high density, granulate, recycled | ref: polyethylene, high density, granulate, recycled | unit: kilogram | loc: Europe without Switzerland
#     5 | name: polyethylene production, low density, granulate | ref: polyethylene, low density, granulate | unit: kilogram | loc: RER
#     6 | name: polyethylene production, low density, granulate | ref: polyethylene, low density, granulate | unit: kilogram | loc: RoW
#     7 | name: polyethylene production, high density, granulate | ref: polyethylene, high density, granulate | unit: kilogram | loc: RER
#     8 | name: polyethylene production, high density, granulate | ref: polyethylene, high density, granulate | unit: kilogram | loc: RoW
#     9 | name: polyethylene production, linear low density, granulate | ref: polyethylene, linear low density, granulate | unit: kilogram | loc: RER
#    10 | name: polyethylene production, linear low density, granulate | ref: polyethylene, linear low density, granulate | unit: kilogram | loc: RoW
#    11 | name: polyethylene production, low density, granulate | ref: steam, in chemical industry | unit: kilogram | loc: RER
#    12 | name: polyethylene production, low density, granulate | ref: steam, in chemical industry | unit: kilogram | loc: RoW
#
#   → Selected [8]: polyethylene production, high density, granulate | RoW
#
# ==========================================================================================
# extrusion_pipes : extrusion plastic pipes market
#     0 | name: market for extrusion, plastic pipes | ref: extrusion, plastic pipes | unit: kilogram | loc: GLO
#
#   → Selected [0]: market for extrusion, plastic pipes | GLO
#
# ==========================================================================================
# reinforcing_steel : reinforcing steel production
#     0 | name: reinforcing steel production | ref: reinforcing steel | unit: kilogram | loc: Europe without Austria
#     1 | name: reinforcing steel production | ref: reinforcing steel | unit: kilogram | loc: AT
#     2 | name: reinforcing steel production | ref: reinforcing steel | unit: kilogram | loc: RoW
#     3 | name: steel production, electric, low-alloyed | ref: steel, low-alloyed | unit: kilogram | loc: AT
#     4 | name: steel production, electric, low-alloyed | ref: iron scrap, unsorted | unit: kilogram | loc: AT
#     5 | name: steel production, electric, low-alloyed | ref: electric arc furnace slag, for recovery | unit: kilogram | loc: AT
#     6 | name: steel production, electric, low-alloyed | ref: heat, district or industrial, other than natural gas | unit: megajoule | loc: AT
#     7 | name: hot rolling, steel | ref: hot rolling, steel | unit: kilogram | loc: AT
#     8 | name: hot rolling, steel | ref: iron scrap, unsorted | unit: kilogram | loc: AT
#     9 | name: hot rolling, steel | ref: heat, district or industrial, other than natural gas | unit: megajoule | loc: AT
#    10 | name: rolling mill production | ref: rolling mill | unit: unit | loc: RoW
#    11 | name: rolling mill production | ref: rolling mill | unit: unit | loc: RER
#    12 | name: wind power plant construction, 800kW, fixed parts | ref: wind power plant, 800kW, fixed parts | unit: unit | loc: GLO
#    13 | name: anaerobic digestion plant construction, agriculture, with methane recovery | ref: anaerobic digestion plant, agriculture, with methane recovery | unit: unit | loc: CH
#    14 | name: hydropower plant construction, reservoir | ref: hydropower plant, reservoir | unit: unit | loc: CH
#    15 | name: heat pump production, brine-water, 10kW | ref: heat pump, brine-water, 10kW | unit: unit | loc: CH
#    16 | name: hydropower plant construction, reservoir, alpine region | ref: hydropower plant, reservoir, alpine region | unit: unit | loc: RER
#    17 | name: hydropower plant construction, reservoir, non-alpine regions | ref: hydropower plant, reservoir, non-alpine regions | unit: unit | loc: RER
#    18 | name: electricity production, hydro, run-of-river, renewable energy products | ref: electricity, high voltage, renewable energy products | unit: kilowatt hour | loc: CH
#    19 | name: electricity production, hydro, run-of-river | ref: electricity, high voltage | unit: kilowatt hour | loc: AR
#    20 | name: borehole heat exchanger production, 150m | ref: borehole heat exchanger, 150m | unit: unit | loc: CH
#    21 | name: electricity production, hydro, run-of-river | ref: electricity, high voltage | unit: kilowatt hour | loc: NP
#    22 | name: electricity production, hydro, run-of-river | ref: electricity, high voltage | unit: kilowatt hour | loc: RoW
#    23 | name: electricity production, hydro, run-of-river | ref: electricity, high voltage | unit: kilowatt hour | loc: HR
#    24 | name: electricity production, hydro, run-of-river | ref: electricity, high voltage | unit: kilowatt hour | loc: LV
#
#   → Selected [2]: reinforcing steel production | RoW
#
# ==========================================================================================
# sheet_rolling_steel : sheet rolling steel GLO market
#     0 | name: market for sheet rolling, steel | ref: sheet rolling, steel | unit: kilogram | loc: GLO
#     1 | name: market for sheet rolling, chromium steel | ref: sheet rolling, chromium steel | unit: kilogram | loc: GLO
#     2 | name: market for hot rolling, steel | ref: hot rolling, steel | unit: kilogram | loc: GLO
#     3 | name: power adapter production, for smartphone | ref: power adapter, for smartphone | unit: unit | loc: GLO
#
#   → Selected [0]: market for sheet rolling, steel | GLO
#
# ==========================================================================================
# ...
#   infra / SF6_INPUT       2.990e-09   market for sulfur hexafluoride, liquid [RER]
#   emis  / SF6_AIR         2.990e-09   Sulfur hexafluoride ('air', 'non-urban air or from high stacks')
#   emis  / N2O_AIR         4.900e-08   Dinitrogen monoxide ('air', 'non-urban air or from high stacks')
#   emis  / OZONE_AIR       4.150e-08   Ozone ('air', 'non-urban air or from high stacks')
#
# ✓ Activity created in 'hydrogen foreground'
# Custom electricity activity: 'electricity market, GB custom mix (2025-12-05T12:00:00)' (kilowatt hour, GB, None)
# Selected technologies for LCA: ['PEM operation']
#   Found: PEM operation
# Electricity source scores, one-off Brightway LCAs
# ------------------------------------------------
#   GAS                    0.557950 kg CO2eq/kWh | electricity production, natural gas, conventional power plant [GB]
#   COAL                   1.060537 kg CO2eq/kWh | electricity production, hard coal [GB]
#   NUCLEAR                0.007409 kg CO2eq/kWh | electricity production, nuclear, boiling water reactor [GB]
#   WIND_GT3_ONSHORE       0.023770 kg CO2eq/kWh | electricity production, wind, >3MW turbine, onshore [GB]
#   WIND_13_OFFSHORE       0.017134 kg CO2eq/kWh | electricity production, wind, 1-3MW turbine, offshore [GB]
#   WIND_13_ONSHORE        0.014466 kg CO2eq/kWh | electricity production, wind, 1-3MW turbine, onshore [GB]
#   WIND_EMB               0.013866 kg CO2eq/kWh | electricity production, wind, <1MW turbine, onshore [GB]
#   HYDRO                  0.004382 kg CO2eq/kWh | electricity production, hydro, run-of-river [GB]
#   IMPORTS_FR             0.074095 kg CO2eq/kWh | electricity, high voltage, import from FR [IT]
#   IMPORTS_IE             0.351764 kg CO2eq/kWh | electricity, high voltage, import from IE [GB]
#   IMPORTS_NL             0.478874 kg CO2eq/kWh | electricity, high voltage, import from NL [GB]
#   BIOMASS                0.055098 kg CO2eq/kWh | heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014 [GB]
#   OTHER                  1.399071 kg CO2eq/kWh | electricity production, oil [GB]
#   SOLAR                  0.079834 kg CO2eq/kWh | electricity production, photovoltaic, 570kWp open ground installation, multi-Si [GB]
#   STORAGE                0.466189 kg CO2eq/kWh | electricity production, hydro, pumped storage [GB]
# Technology decomposition, one-off Brightway LCAs
# ------------------------------------------------
#
# PEM operation:
#   TIME-VARYING: 54.0 kilowatt hour | market for electricity, low voltage [GB] | ref: electricity, low voltage
#   non-electricity score : 0.453470 kg CO2eq/kg H2
#   direct electricity    : 54.000000 kWh/kg H2
#   electricity exchanges : 1
# Running CHEAP batch for 12 timeslice(s): 2025_api_rep_wind_days
# Technologies: ['PEM operation']
#
#   [   1/12] 2025-12-05 12:00:00  elec=0.285952 kg CO2eq/kWh
#   [  12/12] 2025-10-12 12:00:00  elec=0.368776 kg CO2eq/kWh
#
# Completed 12/12 timeslices (cheap method).
# Validation skipped. Set VALIDATE_CHEAP_METHOD=True in dashboard_config.py.
# Saved Carbon-Intensity-API custom-grid LCA results to:
# /Users/louis/brightway-hydrogen/split up version/custom_grid_lca_outputs/custom_grid_lca_carbon_api_regional_auto_r13_cheap_2025_api_rep_wind_days.csv
# Seasonal wind-contribution analysis for 2025
# Wind = API aggregate wind percentage, plus WIND_EMB if configured
# ==============================================================================
#
# winter  (90 days)
# ------------------------------------------------------------------------------
#   Season average wind            :  28.48%
#     closest day                  : 2025-12-05  (28.61%)
#   Top 10% wind days (n= 9)        :  51.56%
#     closest day                  : 2025-02-21  (51.94%)
#   Bottom 10% wind days (n= 9)     :   6.60%
#     closest day                  : 2025-01-19  ( 5.50%)
#
# spring  (92 days)
# ------------------------------------------------------------------------------
#   Season average wind            :  19.46%
#     closest day                  : 2025-03-15  (19.33%)
#   Top 10% wind days (n=10)        :  44.02%
#     closest day                  : 2025-04-16  (45.65%)
#   Bottom 10% wind days (n=10)     :   4.74%
#     closest day                  : 2025-03-03  ( 4.95%)
#
# summer  (92 days)
# ------------------------------------------------------------------------------
#   Season average wind            :  20.37%
#     closest day                  : 2025-08-29  (20.62%)
#   Top 10% wind days (n=10)        :  45.86%
#     closest day                  : 2025-08-31  (45.52%)
#   Bottom 10% wind days (n=10)     :   4.69%
#     closest day                  : 2025-07-10  ( 4.67%)
#
# autumn  (91 days)
# ------------------------------------------------------------------------------
#   Season average wind            :  32.65%
#     closest day                  : 2025-09-24  (32.88%)
#   Top 10% wind days (n=10)        :  56.68%
#     closest day                  : 2025-11-29  (56.10%)
#   Bottom 10% wind days (n=10)     :   5.03%
#     closest day                  : 2025-10-12  ( 3.92%)
#
# Representative days for year_average LCA (12 days):
#   winter  average  2025-12-05  (~28.48% wind)
#   winter  top10    2025-02-21  (~51.56% wind)
#   winter  bottom10 2025-01-19  (~ 6.60% wind)
#   spring  average  2025-03-15  (~19.46% wind)
#   spring  top10    2025-04-16  (~44.02% wind)
#   spring  bottom10 2025-03-03  (~ 4.74% wind)
#   summer  average  2025-08-29  (~20.37% wind)
#   summer  top10    2025-08-31  (~45.86% wind)
#   summer  bottom10 2025-07-10  (~ 4.69% wind)
#   autumn  average  2025-09-24  (~32.65% wind)
#   autumn  top10    2025-11-29  (~56.68% wind)
#   autumn  bottom10 2025-10-12  (~ 5.03% wind)
# Master Dashboard
# ----------------
# Project:                 hydrogen-smr
# Foreground DB:           hydrogen foreground
# Build foreground DB:     True
# Run reference LCA:       False
# Run grid scenario LCA:   True
# Grid data source:        carbon_api | notebook: 3.1.custom_grid_carbon_intensity_api.ipynb
# Run wind/grid LCA:       True
# Run price data:          True
# Grid method:             cheap | loss factor: 1.0316426921769999
# Grid output pattern:     custom_grid_lca_carbon_api_*.csv
# Carbon API scope:        regional_auto | cache: True
# Wind/grid method:        cheap
# Selected grid techs:     ['PEM operation']
# Wind/grid mode:          both (blended + switching) | electrolyser(s): ['AE operation']
# Price output dir:        price_outputs
# Elexon provider:         APXMIDP | fallback: N2EXMIDP
# Cost case:               central | wind: central
# (Wind cost details: run 5.prices.ipynb -> price_outputs/wind_annual_costs_per_MW.csv)
#
# Current Brightway project: hydrogen-smr
# Using ecoinvent database: ecoinvent-3.9.1-apos
# Using biosphere database: ecoinvent-3.9.1-biosphere
# Using foreground database: hydrogen foreground
# Using LCIA method: ('ecoinvent-3.9.1', 'IPCC 2021 no LT', 'climate change no LT', 'global warming potential (GWP100) no LT')
# Wind/grid run
# -------------
# LCA mode:                   both
# Grid time mode:             year_average
# Grid data source:           carbon_api
# Window:                     2025-01-01 00:00:00 -> 2025-12-29 00:00:00
# Electrolyser capacity (kW): 1000.0
# Wind installed cap. (kW):   1000.0
# Electrolyser tech(s):       ['AE operation']
# Using Carbon Intensity API grid rows from 4.1.
# Selected rows: 12  (2025_api_rep_wind_days)
# Start: 2025-01-19 12:00:00
# End  : 2025-12-05 12:00:00
# Renewables.ninja session created. Source: prompt; token length: 40
# Status: 200
# URL: https://www.renewables.ninja/api/data/wind?lat=51.732&lon=-0.3711&date_from=2025-01-19&date_to=2025-12-05&dataset=merra2&capacity=1000.0&height=80&turbine=Vestas+V90+2000&format=json
# Mean wind fraction: 0.4054486666666666
# Mean grid fraction: 0.5945513333333333
# [blended] 12 days; showing first 8 for preview.
# [switching] 12 days; showing first 8 for preview.
#     0 | name: electricity production, wind, 1-3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     1 | name: electricity production, wind, 1-3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: NP
#     2 | name: electricity production, wind, 1-3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: RoW
#     3 | name: electricity production, wind, 1-3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: CA-QC
#     4 | name: electricity production, wind, 1-3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: CO
#     5 | name: electricity production, wind, 1-3MW turbine, offshore | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     6 | name: electricity production, wind, >3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     7 | name: electricity production, wind, <1MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: GB
#     8 | name: electricity production, wind, 1-3MW turbine, offshore | ref: electricity, high voltage | unit: kilowatt hour | loc: RoW
#     9 | name: electricity production, wind, >3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: RoW
#    10 | name: electricity production, wind, 1-3MW turbine, offshore | ref: electricity, high voltage | unit: kilowatt hour | loc: PL
#    11 | name: electricity production, wind, 1-3MW turbine, offshore | ref: electricity, high voltage | unit: kilowatt hour | loc: EE
#    12 | name: electricity production, wind, >3MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: CA-QC
#    13 | name: electricity production, wind, <1MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: RoW
#    14 | name: electricity production, wind, <1MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: ID
#    15 | name: electricity production, wind, <1MW turbine, onshore | ref: electricity, high voltage | unit: kilowatt hour | loc: CA-QC
#
# Selected wind background process:
# 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, GB, None)
#
# Created foreground wind electricity process:
# 'electricity, wind turbine source, wind/grid electrolyser' (kilowatt hour, GB, None)
# Method: ('ecoinvent-3.9.1', 'IPCC 2021 no LT', 'climate change no LT', 'global warming potential (GWP100) no LT')
# Electrolyser tech(s): ['AE operation']
#   AE operation: 'Hydrogen production, alkaline electrolysis Hermesmann' (kilogram, DE, None)
#
# Direct electricity exchanges that will be swapped (both mode):
# -- AE operation --
#   TIME-VARYING: 51.8 kilowatt hour | market for electricity, low voltage [DE] | ref: electricity, low voltage
# Cheap method: pre-computing one-off LCA scores...
#   wind electricity score: 0.014466 kg CO2e/kWh
#
# Electricity source scores, one-off Brightway LCAs
# ------------------------------------------------
#   GAS                    0.557950 kg CO2eq/kWh | electricity production, natural gas, conventional power plant [GB]
#   COAL                   1.060537 kg CO2eq/kWh | electricity production, hard coal [GB]
#   NUCLEAR                0.007409 kg CO2eq/kWh | electricity production, nuclear, boiling water reactor [GB]
#   WIND_GT3_ONSHORE       0.023770 kg CO2eq/kWh | electricity production, wind, >3MW turbine, onshore [GB]
#   WIND_13_OFFSHORE       0.017134 kg CO2eq/kWh | electricity production, wind, 1-3MW turbine, offshore [GB]
#   WIND_13_ONSHORE        0.014466 kg CO2eq/kWh | electricity production, wind, 1-3MW turbine, onshore [GB]
#   WIND_EMB               0.013866 kg CO2eq/kWh | electricity production, wind, <1MW turbine, onshore [GB]
#   HYDRO                  0.004382 kg CO2eq/kWh | electricity production, hydro, run-of-river [GB]
#   IMPORTS_FR             0.074095 kg CO2eq/kWh | electricity, high voltage, import from FR [IT]
#   IMPORTS_IE             0.351764 kg CO2eq/kWh | electricity, high voltage, import from IE [GB]
#   IMPORTS_NL             0.478874 kg CO2eq/kWh | electricity, high voltage, import from NL [GB]
#   BIOMASS                0.055098 kg CO2eq/kWh | heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014 [GB]
#   OTHER                  1.399071 kg CO2eq/kWh | electricity production, oil [GB]
#   SOLAR                  0.079834 kg CO2eq/kWh | electricity production, photovoltaic, 570kWp open ground installation, multi-Si [GB]
#   STORAGE                0.466189 kg CO2eq/kWh | electricity production, hydro, pumped storage [GB]
# Technology decomposition, one-off Brightway LCAs
# ------------------------------------------------
#
# AE operation:
#   TIME-VARYING: 51.8 kilowatt hour | market for electricity, low voltage [DE] | ref: electricity, low voltage
#   non-electricity score : 0.430133 kg CO2eq/kg H2
#   direct electricity    : 51.800000 kWh/kg H2
#   electricity exchanges : 1
#
# --- Running blended CHEAP LCA for 12 slices across 1 tech(s): ['AE operation']...
# Rule: electrolyser always 100%; wind fraction = min(wind/electrolyser, 1).
#
# [ 1/12] 2025-12-05 12:00:00 | AE operation    | wind=428.6 kW | wf=0.429 | gf=0.571 → GWP100=9.2145 kg CO2e/kg H2
# [ 2/12] 2025-02-21 12:00:00 | AE operation    | wind=948.1 kW | wf=0.948 | gf=0.052 → GWP100=1.5217 kg CO2e/kg H2
# [ 3/12] 2025-01-19 12:00:00 | AE operation    | wind=122.8 kW | wf=0.123 | gf=0.877 → GWP100=20.1714 kg CO2e/kg H2
# [ 4/12] 2025-03-15 12:00:00 | AE operation    | wind=425.0 kW | wf=0.425 | gf=0.575 → GWP100=8.2414 kg CO2e/kg H2
# [ 5/12] 2025-04-16 12:00:00 | AE operation    | wind=850.6 kW | wf=0.851 | gf=0.149 → GWP100=2.2007 kg CO2e/kg H2
# [ 6/12] 2025-03-03 12:00:00 | AE operation    | wind=21.6 kW | wf=0.022 | gf=0.978 → GWP100=17.4474 kg CO2e/kg H2
# [ 7/12] 2025-08-29 12:00:00 | AE operation    | wind=199.2 kW | wf=0.199 | gf=0.801 → GWP100=9.3980 kg CO2e/kg H2
# [ 8/12] 2025-08-31 12:00:00 | AE operation    | wind=725.0 kW | wf=0.725 | gf=0.275 → GWP100=2.2972 kg CO2e/kg H2
# [ 9/12] 2025-07-10 12:00:00 | AE operation    | wind=59.2 kW | wf=0.059 | gf=0.941 → GWP100=13.7587 kg CO2e/kg H2
# [10/12] 2025-09-24 12:00:00 | AE operation    | wind=447.0 kW | wf=0.447 | gf=0.553 → GWP100=7.5340 kg CO2e/kg H2
# [11/12] 2025-11-29 12:00:00 | AE operation    | wind=568.5 kW | wf=0.568 | gf=0.432 → GWP100=3.0941 kg CO2e/kg H2
# [12/12] 2025-10-12 12:00:00 | AE operation    | wind=69.5 kW | wf=0.070 | gf=0.930 → GWP100=18.2565 kg CO2e/kg H2
#
# --- Running switching CHEAP LCA for 12 slices across 1 tech(s): ['AE operation']...
# Switching rule: wind if wind_power_kw >= 100.0 kW, else grid.
#
# [ 1/12] 2025-12-05 12:00:00 | AE operation    | wind=428.6 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 2/12] 2025-02-21 12:00:00 | AE operation    | wind=948.1 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 3/12] 2025-01-19 12:00:00 | AE operation    | wind=122.8 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 4/12] 2025-03-15 12:00:00 | AE operation    | wind=425.0 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 5/12] 2025-04-16 12:00:00 | AE operation    | wind=850.6 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 6/12] 2025-03-03 12:00:00 | AE operation    | wind=21.6 kW | source=grid → GWP100=17.8071 kg CO2e/kg H2
# [ 7/12] 2025-08-29 12:00:00 | AE operation    | wind=199.2 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 8/12] 2025-08-31 12:00:00 | AE operation    | wind=725.0 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [ 9/12] 2025-07-10 12:00:00 | AE operation    | wind=59.2 kW | source=grid → GWP100=14.5506 kg CO2e/kg H2
# [10/12] 2025-09-24 12:00:00 | AE operation    | wind=447.0 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [11/12] 2025-11-29 12:00:00 | AE operation    | wind=568.5 kW | source=wind → GWP100=1.1795 kg CO2e/kg H2
# [12/12] 2025-10-12 12:00:00 | AE operation    | wind=69.5 kW | source=grid → GWP100=19.5327 kg CO2e/kg H2
#
# Completed.
# Saved blended (cheap) results (12 rows) to:
# /Users/louis/brightway-hydrogen/split up version/blended_wind_grid_lca_outputs/wind_grid_lca_blended_cheap_2025_api_rep_wind_days.csv
# Saved switching (cheap) results (12 rows) to:
# /Users/louis/brightway-hydrogen/split up version/hybrid_wind_grid_lca_outputs/wind_grid_lca_switching_cheap_2025_api_rep_wind_days.csv

# %% [markdown]
# ## Load the latest result CSVs

# %%
from pathlib import Path
import pandas as pd

def latest_csv(folder, patterns=None):
    folder = Path(folder)
    if not folder.exists():
        return None
    patterns = patterns or ["*.csv"]
    if isinstance(patterns, str):
        patterns = [patterns]
    files = []
    for pattern in patterns:
        files.extend(folder.glob(pattern))
    # de-duplicate while preserving Path objects
    files = list({p.resolve(): p for p in files}.values())
    files = sorted(files, key=lambda p: p.stat().st_mtime, reverse=True)
    return files[0] if files else None

grid_patterns = getattr(cfg, "GRID_OUTPUT_GLOBS", [getattr(cfg, "GRID_OUTPUT_GLOB", "*.csv")])
grid_csv = latest_csv(GRID_OUTPUT_DIR, grid_patterns)
print("Custom-grid source: ", getattr(cfg, "GRID_DATA_SOURCE", "csv"))
print("Custom-grid pattern:", grid_patterns)
print("Custom-grid CSV:    ", grid_csv)
if grid_csv is not None:
    grid_df_results = pd.read_csv(grid_csv, parse_dates=["datetime"]).set_index("datetime")
    display(grid_df_results.head())
else:
    grid_df_results = None
    print(f"  (no matching output found — run {getattr(cfg, 'GRID_NOTEBOOK', 'custom_grid.ipynb')})")

if WIND_LCA_MODE == "both":
    # Load both blended and switching CSVs
    blended_csv = latest_csv(WIND_OUTPUT_DIR_BLENDED)
    switching_csv = latest_csv(WIND_OUTPUT_DIR_SWITCHING)
    print("Wind/grid CSV (blended):  ", blended_csv)
    print("Wind/grid CSV (switching):", switching_csv)
    
    dfs = []
    if blended_csv is not None:
        dfs.append(pd.read_csv(blended_csv, parse_dates=["datetime"]))
    if switching_csv is not None:
        dfs.append(pd.read_csv(switching_csv, parse_dates=["datetime"]))
    
    if dfs:
        wind_df_results = pd.concat(dfs, ignore_index=True)
        print(f"  Combined: {len(wind_df_results)} rows")
        display(wind_df_results.head())
    else:
        wind_df_results = None
        print("  (no output found — run wind_power.ipynb)")
else:
    wind_folder = (WIND_OUTPUT_DIR_BLENDED if WIND_LCA_MODE == "blended"
                   else WIND_OUTPUT_DIR_SWITCHING)
    wind_csv = latest_csv(wind_folder)
    print("Wind/grid CSV:      ", wind_csv)
    if wind_csv is not None:
        wind_df_results = pd.read_csv(wind_csv, parse_dates=["datetime"])
        display(wind_df_results.head())
    else:
        wind_df_results = None
        print("  (no output found — run wind_power.ipynb)")

# Attach representative-day labels (REP_SEASON / REP_KIND) to the wind data.
# The wind CSVs don't carry these columns, but the grid CSV does, and both share
# the same half-hour timestamps. Merging on datetime lets every plot/table align
# on the canonical (season, kind) identity instead of fragile raw-date matching.
if (wind_df_results is not None and not wind_df_results.empty
        and grid_df_results is not None and not grid_df_results.empty
        and "REP_SEASON" in grid_df_results.columns
        and "REP_SEASON" not in wind_df_results.columns):
    wind_df_results["datetime"] = pd.to_datetime(wind_df_results["datetime"])
    rep_map = (grid_df_results.reset_index()[["datetime", "REP_SEASON", "REP_KIND"]]
               .drop_duplicates("datetime"))
    wind_df_results = wind_df_results.merge(rep_map, on="datetime", how="left")
    matched = wind_df_results["REP_SEASON"].notna().sum()
    print(f"  Attached REP_SEASON/REP_KIND to wind data: "
          f"{matched}/{len(wind_df_results)} rows matched.")
# Out:
# Custom-grid source:  carbon_api
# Custom-grid pattern: ['custom_grid_lca_carbon_api_*.csv']
# Custom-grid CSV:     custom_grid_lca_outputs/custom_grid_lca_carbon_api_regional_auto_r13_cheap_2025_api_rep_wind_days.csv
#                      carbon_intensity  custom_electricity_score  \
# datetime
# 2025-12-05 12:00:00        176.812500                  0.285952
# 2025-02-21 12:00:00         90.604167                  0.141721
# 2025-01-19 12:00:00        286.854167                  0.432444
# 2025-03-15 12:00:00        142.375000                  0.251581
# 2025-04-16 12:00:00         78.562500                  0.146449
#
#                      custom_electricity_input_kwh_per_kwh      api_scope  \
# datetime
# 2025-12-05 12:00:00                              1.031729  regional_auto
# 2025-02-21 12:00:00                              1.031600  regional_auto
# 2025-01-19 12:00:00                              1.031213  regional_auto
# 2025-03-15 12:00:00                              1.031793  regional_auto
# 2025-04-16 12:00:00                              1.031557  regional_auto
#
#                      api_region_id api_region_name  wind_lat  wind_lon  \
# datetime
# 2025-12-05 12:00:00             13          London    51.732   -0.3711
# 2025-02-21 12:00:00             13          London    51.732   -0.3711
# 2025-01-19 12:00:00             13          London    51.732   -0.3711
# 2025-03-15 12:00:00             13          London    51.732   -0.3711
# 2025-04-16 12:00:00             13          London    51.732   -0.3711
#
#                      api_total_perc  carbon_intensity_forecast  ...  \
# datetime                                                        ...
# 2025-12-05 12:00:00      100.008333                 176.812500  ...
# 2025-02-21 12:00:00       99.995833                  90.604167  ...
# 2025-01-19 12:00:00       99.958333                 286.854167  ...
# 2025-03-15 12:00:00      100.014583                 142.375000  ...
# 2025-04-16 12:00:00       99.991667                  78.562500  ...
#
#                      NUCLEAR_perc  WIND_perc WIND_EMB_perc HYDRO_perc  \
# datetime
# 2025-12-05 12:00:00      9.500000  28.610417           0.0   0.127083
# 2025-02-21 12:00:00     15.095833  51.935417           0.0   0.100000
# 2025-01-19 12:00:00      6.602083   5.497917           0.0   0.127083
# 2025-03-15 12:00:00      3.447917  19.331250           0.0   0.172917
# 2025-04-16 12:00:00     12.820833  45.647917           0.0   0.122917
#
#                     IMPORTS_perc  BIOMASS_perc  OTHER_perc  SOLAR_perc  \
# datetime
# 2025-12-05 12:00:00    15.943750      1.866667         0.0    1.797917
# 2025-02-21 12:00:00    12.097917      1.000000         0.0    1.835417
# 2025-01-19 12:00:00    14.910417      3.793750         0.0    0.300000
# 2025-03-15 12:00:00    49.589583      0.000000         0.0    4.025000
# 2025-04-16 12:00:00    14.133333      1.250000         0.0    8.870833
#
#                      STORAGE_perc  PEM operation
# datetime
# 2025-12-05 12:00:00           0.0      15.894904
# 2025-02-21 12:00:00           0.0       8.106379
# 2025-01-19 12:00:00           0.0      23.805439
# 2025-03-15 12:00:00           0.0      14.038855
# 2025-04-16 12:00:00           0.0       8.361697
#
# [5 rows x 39 columns]
# Wind/grid CSV (blended):   blended_wind_grid_lca_outputs/wind_grid_lca_blended_cheap_2025_api_rep_wind_days.csv
# Wind/grid CSV (switching): hybrid_wind_grid_lca_outputs/wind_grid_lca_switching_cheap_2025_api_rep_wind_days.csv
#   Combined: 24 rows
#              datetime lca_mode electrolyser_tech                scenario  \
# 0 2025-01-19 12:00:00  blended      AE operation  AE operation (blended)
# 1 2025-02-21 12:00:00  blended      AE operation  AE operation (blended)
# 2 2025-03-03 12:00:00  blended      AE operation  AE operation (blended)
# 3 2025-03-15 12:00:00  blended      AE operation  AE operation (blended)
# 4 2025-04-16 12:00:00  blended      AE operation  AE operation (blended)
#
#    wind_power_kw  grid_carbon_intensity_gco2_per_kwh electricity_source  \
# 0        122.826                          286.854167            blended
# 1        948.082                           90.604167            blended
# 2         21.632                          215.833333            blended
# 3        425.043                          142.375000            blended
# 4        850.619                           78.562500            blended
#
#    wind_fraction  grid_fraction  wind_used_kw  grid_topup_kw  surplus_wind_kw  \
# 0       0.122826       0.877174       122.826        877.174              0.0
# 1       0.948082       0.051918       948.082         51.918              0.0
# 2       0.021632       0.978368        21.632        978.368              0.0
# 3       0.425043       0.574957       425.043        574.957              0.0
# 4       0.850619       0.149381       850.619        149.381              0.0
#
#    wind_above_minimum  gwp100_kgco2e_per_kg_h2  electricity_exchanges_swapped  \
# 0                 NaN                20.171387                              1
# 1                 NaN                 1.521696                              1
# 2                 NaN                17.447435                              1
# 3                 NaN                 8.241416                              1
# 4                 NaN                 2.200738                              1
#
#    direct_electricity_kwh_per_kg_h2  wind_electricity_kwh_per_kg_h2  \
# 0                              51.8                        6.362387
# 1                              51.8                       49.110648
# 2                              51.8                        1.120538
# 3                              51.8                       22.017227
# 4                              51.8                       44.062064
#
#    grid_electricity_kwh_per_kg_h2  temporary_grid_activity_code  \
# 0                       45.437613                           NaN
# 1                        2.689352                           NaN
# 2                       50.679462                           NaN
# 3                       29.782773                           NaN
# 4                        7.737936                           NaN
#
#    minimum_required_wind_kw
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#   Attached REP_SEASON/REP_KIND to wind data: 24/24 rows matched.

# %% [markdown]
# ## Plot: custom-grid LCA GWP100 over selected timeslices

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

if grid_df_results is None or grid_df_results.empty:
    print("Skipping custom-grid plot — no results loaded.")
else:
    metadata_cols = {
        "carbon_intensity", "custom_electricity_score",
        "custom_electricity_input_kwh_per_kwh", "REP_SEASON", "REP_KIND",
    }
    tech_cols = [c for c in grid_df_results.columns if c not in metadata_cols]
    
    # Check if we have representative day info
    if "REP_SEASON" in grid_df_results.columns and "REP_KIND" in grid_df_results.columns:
        # Create subplots for each representative day
        runs = sorted(grid_df_results.groupby(["REP_SEASON", "REP_KIND"]).groups.keys())
        n_runs = len(runs)
        n_cols = 4
        n_rows = (n_runs + n_cols - 1) // n_cols
        
        fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 3.5*n_rows))
        axes = axes.flatten()
        
        for ax_idx, (season, kind) in enumerate(runs):
            rep_data = grid_df_results[
                (grid_df_results["REP_SEASON"] == season) & 
                (grid_df_results["REP_KIND"] == kind)
            ]
            
            ax = axes[ax_idx]
            for tech in tech_cols:
                ax.plot(rep_data.index, rep_data[tech], marker="o", label=tech,
                       linewidth=1.5, markersize=3)
            
            ax.set_title(f"{season} - {kind.upper()}", fontsize=11, fontweight="bold")
            ax.set_ylabel("GWP100 (kg CO2e/kg H2)", fontsize=9)
            ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
            ax.tick_params(axis="x", labelsize=8)
            ax.tick_params(axis="y", labelsize=8)
            ax.grid(True, alpha=0.3)
            if ax_idx == 0:
                ax.legend(fontsize=8, loc="best")
        
        # Hide unused subplots
        for ax_idx in range(len(runs), len(axes)):
            axes[ax_idx].set_visible(False)
        
        fig.suptitle(f"Custom-grid LCA — {METHOD_MODE} method — 12 representative days",
                    fontsize=13, fontweight="bold", y=0.995)
        fig.tight_layout()
        plt.show()
    
    else:
        # Fallback: single aggregated plot if no rep day info
        fig, ax1 = plt.subplots(figsize=(13, 6))
        for tech in tech_cols:
            ax1.plot(grid_df_results.index, grid_df_results[tech],
                     label=tech, color=H.TECH_COLOURS.get(tech),
                     linewidth=1.8, marker="o", markersize=3)

        ax1.set_xlabel("Time (UTC)", fontsize=11)
        ax1.set_ylabel("GWP100  (kg CO2eq / kg H2)", fontsize=11)
        ax1.set_title(f"Hydrogen GWP100 over selected timeslices — {METHOD_MODE} method",
                      fontsize=13)
        ax1.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
        ax1.xaxis.set_major_locator(mdates.HourLocator(interval=2))
        plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha="right")
        ax1.legend(loc="upper right", fontsize=10, framealpha=0.85)
        ax1.grid(True, linestyle="--", alpha=0.4)

        if "custom_electricity_score" in grid_df_results.columns \
           and grid_df_results["custom_electricity_score"].notna().any():
            ax2 = ax1.twinx()
            ax2.plot(grid_df_results.index, grid_df_results["custom_electricity_score"],
                     color="grey", linewidth=1.2, linestyle=":",
                     label="Custom electricity score (kg CO2eq/kWh)")
            ax2.set_ylabel("Custom electricity score  (kg CO2eq/kWh)",
                           fontsize=10, color="grey")
            ax2.tick_params(axis="y", labelcolor="grey")
            ax2.legend(loc="upper left", fontsize=9, framealpha=0.75)
        elif "carbon_intensity" in grid_df_results.columns \
             and grid_df_results["carbon_intensity"].notna().any():
            ax2 = ax1.twinx()
            ax2.plot(grid_df_results.index, grid_df_results["carbon_intensity"],
                     color="grey", linewidth=1.2, linestyle=":",
                     label="Grid CI (g CO2eq/kWh)")
            ax2.set_ylabel("Grid carbon intensity (g CO2eq/kWh)", fontsize=10, color="grey")
            ax2.tick_params(axis="y", labelcolor="grey")
            ax2.legend(loc="upper left", fontsize=9, framealpha=0.75)

        fig.tight_layout()
        plt.show()

# %% [markdown]
# ## Plot: wind/grid LCA GWP100 over the 48 slices

# %%
# === DIAGNOSTIC: What's being loaded and plotted ===
print("=" * 80)
print("DATA LOADING DIAGNOSTICS")
print("=" * 80)

print("\n1. CONFIG SETTINGS:")
print(f"   WIND_LCA_MODE = {WIND_LCA_MODE}")
print(f"   WIND_OUTPUT_DIR_BLENDED = {WIND_OUTPUT_DIR_BLENDED}")
print(f"   WIND_OUTPUT_DIR_SWITCHING = {WIND_OUTPUT_DIR_SWITCHING}")

print("\n2. WIND DATA LOADED:")
if wind_df_results is not None and not wind_df_results.empty:
    print(f"   Shape: {wind_df_results.shape}")
    print(f"   Columns: {list(wind_df_results.columns)}")
    print(f"\n   Unique lca_modes: {sorted(wind_df_results['lca_mode'].unique())}")
    for mode in sorted(wind_df_results['lca_mode'].unique()):
        count = len(wind_df_results[wind_df_results['lca_mode'] == mode])
        techs = wind_df_results[wind_df_results['lca_mode'] == mode]['electrolyser_tech'].unique()
        print(f"     - {mode}: {count} rows, techs={list(techs)}")
else:
    print("   (No wind data loaded)")

print("\n3. GRID DATA LOADED:")
if grid_df_results is not None and not grid_df_results.empty:
    print(f"   Shape: {grid_df_results.shape}")
    metadata_cols = {"carbon_intensity", "custom_electricity_score",
                     "custom_electricity_input_kwh_per_kwh", "REP_SEASON", "REP_KIND"}
    tech_cols = [c for c in grid_df_results.columns if c not in metadata_cols]
    print(f"   Tech columns: {tech_cols}")
    print(f"   REP_SEASON values: {sorted(grid_df_results['REP_SEASON'].unique())}")
    print(f"   REP_KIND values: {sorted(grid_df_results['REP_KIND'].unique())}")
else:
    print("   (No grid data loaded)")

print("\n4. PLOT GRID LAYOUT:")
print("   Column 0: Blended wind/grid mode")
print("   Column 1: Switching wind/grid mode")
print("   Column 2: Custom grid LCA")

print("\n" + "=" * 80)
print("If any columns are empty in the plot grid, check the diagnostics above.")
print("=" * 80 + "\n")
# Out:
# ================================================================================
# DATA LOADING DIAGNOSTICS
# ================================================================================
#
# 1. CONFIG SETTINGS:
#    WIND_LCA_MODE = both
#    WIND_OUTPUT_DIR_BLENDED = blended_wind_grid_lca_outputs
#    WIND_OUTPUT_DIR_SWITCHING = hybrid_wind_grid_lca_outputs
#
# 2. WIND DATA LOADED:
#    Shape: (24, 22)
#    Columns: ['datetime', 'lca_mode', 'electrolyser_tech', 'scenario', 'wind_power_kw', 'grid_carbon_intensity_gco2_per_kwh', 'electricity_source', 'wind_fraction', 'grid_fraction', 'wind_used_kw', 'grid_topup_kw', 'surplus_wind_kw', 'wind_above_minimum', 'gwp100_kgco2e_per_kg_h2', 'electricity_exchanges_swapped', 'direct_electricity_kwh_per_kg_h2', 'wind_electricity_kwh_per_kg_h2', 'grid_electricity_kwh_per_kg_h2', 'temporary_grid_activity_code', 'minimum_required_wind_kw', 'REP_SEASON', 'REP_KIND']
#
#    Unique lca_modes: ['blended', 'switching']
#      - blended: 12 rows, techs=['AE operation']
#      - switching: 12 rows, techs=['AE operation']
#
# 3. GRID DATA LOADED:
#    Shape: (12, 39)
#    Tech columns: ['api_scope', 'api_region_id', 'api_region_name', 'wind_lat', 'wind_lon', 'api_total_perc', 'carbon_intensity_forecast', 'carbon_intensity_actual', 'carbon_intensity_index', 'REP_DATE', 'REP_TARGET_WIND_PCT', 'API_ROW_COUNT', 'api_gas', 'api_coal', 'api_biomass', 'api_nuclear', 'api_hydro', 'api_imports', 'api_other', 'api_wind', 'api_solar', 'api_storage', 'GAS_perc', 'COAL_perc', 'NUCLEAR_perc', 'WIND_perc', 'WIND_EMB_perc', 'HYDRO_perc', 'IMPORTS_perc', 'BIOMASS_perc', 'OTHER_perc', 'SOLAR_perc', 'STORAGE_perc', 'PEM operation']
#    REP_SEASON values: ['autumn', 'spring', 'summer', 'winter']
#    REP_KIND values: ['average', 'bottom10', 'top10']
#
# 4. PLOT GRID LAYOUT:
#    Column 0: Blended wind/grid mode
#    Column 1: Switching wind/grid mode
#    Column 2: Custom grid LCA
#
# ================================================================================
# If any columns are empty in the plot grid, check the diagnostics above.
# ================================================================================

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np

if wind_df_results is None or wind_df_results.empty or grid_df_results is None or grid_df_results.empty:
    print("Skipping 12x3 representative day plots — need both wind and grid results.")
else:
    wind_df_results["datetime"] = pd.to_datetime(wind_df_results["datetime"])
    
    # Identify unique representative runs from wind data
    if "REP_SEASON" in wind_df_results.columns and "REP_KIND" in wind_df_results.columns:
        runs = sorted(set(map(tuple,
            wind_df_results[["REP_SEASON", "REP_KIND"]].dropna().itertuples(index=False, name=None))))
        run_labels = [f"{season}\n{kind}" for season, kind in runs]
    else:
        # Fallback: group by unique dates if rep columns not present
        wind_df_results["date_only"] = wind_df_results["datetime"].dt.date
        runs = sorted(wind_df_results["date_only"].unique())
        run_labels = [str(d) for d in runs]
    
    n_runs = len(runs)
    modes = ["blended", "switching", "custom_grid"]
    
    # Create 12 rows × 3 columns grid
    fig, axes = plt.subplots(n_runs, 3, figsize=(18, 3*n_runs))
    if n_runs == 1:
        axes = axes.reshape(1, -1)
    
    for row_idx, run in enumerate(runs):
        # Extract data for this representative run
        if "REP_SEASON" in wind_df_results.columns:
            season, kind = run
            wind_run = wind_df_results[
                (wind_df_results["REP_SEASON"] == season) & 
                (wind_df_results["REP_KIND"] == kind)
            ]
            grid_run = grid_df_results[
                (grid_df_results["REP_SEASON"] == season) & 
                (grid_df_results["REP_KIND"] == kind)
            ]
            run_title = f"{season} - {kind.upper()}"
        else:
            date_val = run
            wind_run = wind_df_results[wind_df_results["date_only"] == date_val]
            grid_run = grid_df_results.loc[grid_df_results.index.date == date_val]
            run_title = str(date_val)
        
        # Column 0: Blended mode
        ax_blended = axes[row_idx, 0]
        blended_df = wind_run[wind_run["lca_mode"] == "blended"]
        if not blended_df.empty:
            for tech in ELECTROLYSER_TECHS:
                tech_data = blended_df[blended_df["electrolyser_tech"] == tech]
                if not tech_data.empty:
                    ax_blended.plot(tech_data["datetime"], tech_data["gwp100_kgco2e_per_kg_h2"],
                                   marker="o", label=tech, markersize=3, linewidth=1.5)
        ax_blended.set_title(f"Blended - {run_title}", fontsize=10, fontweight="bold")
        ax_blended.set_ylabel("GWP100 (kg CO2e/kg H2)", fontsize=9)
        ax_blended.grid(True, alpha=0.3)
        ax_blended.tick_params(axis="x", labelsize=8)
        ax_blended.tick_params(axis="y", labelsize=8)
        if row_idx == 0:
            ax_blended.legend(fontsize=7, loc="best")
        
        # Column 1: Switching mode
        ax_switching = axes[row_idx, 1]
        switching_df = wind_run[wind_run["lca_mode"] == "switching"]
        if not switching_df.empty:
            for tech in ELECTROLYSER_TECHS:
                tech_data = switching_df[switching_df["electrolyser_tech"] == tech]
                if not tech_data.empty:
                    ax_switching.plot(tech_data["datetime"], tech_data["gwp100_kgco2e_per_kg_h2"],
                                     marker="o", label=tech, markersize=3, linewidth=1.5)
        ax_switching.set_title(f"Switching - {run_title}", fontsize=10, fontweight="bold")
        ax_switching.set_ylabel("GWP100 (kg CO2e/kg H2)", fontsize=9)
        ax_switching.grid(True, alpha=0.3)
        ax_switching.tick_params(axis="x", labelsize=8)
        ax_switching.tick_params(axis="y", labelsize=8)
        if row_idx == 0:
            ax_switching.legend(fontsize=7, loc="best")
        
        # Column 2: Custom grid mode
        ax_grid = axes[row_idx, 2]
        if not grid_run.empty:
            grid_run = grid_run.sort_index()
            metadata_cols = {"carbon_intensity", "custom_electricity_score",
                           "custom_electricity_input_kwh_per_kwh", "REP_SEASON", "REP_KIND"}
            tech_cols = [c for c in grid_run.columns if c not in metadata_cols]
            for tech in tech_cols:
                ax_grid.plot(grid_run.index, grid_run[tech], marker="o",
                            label=tech, markersize=3, linewidth=1.5)
        ax_grid.set_title(f"Custom Grid - {run_title}", fontsize=10, fontweight="bold")
        ax_grid.set_ylabel("GWP100 (kg CO2e/kg H2)", fontsize=9)
        ax_grid.grid(True, alpha=0.3)
        ax_grid.tick_params(axis="x", labelsize=8)
        ax_grid.tick_params(axis="y", labelsize=8)
        if row_idx == 0:
            ax_grid.legend(fontsize=7, loc="best")
    
    # Rotate x-axis labels for all bottom row cells
    for col in range(3):
        axes[n_runs-1, col].xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
        plt.setp(axes[n_runs-1, col].xaxis.get_majorticklabels(), rotation=45, ha="right", fontsize=8)
    
    fig.suptitle(f"LCA Results: 12 Representative Days × 3 Modes ({n_runs} runs × 3 comparison modes)",
                 fontsize=14, fontweight="bold", y=0.995)
    fig.tight_layout()
    plt.show()
# Out:
# /var/folders/4k/86frdt4j30v2q39zm0kp7v140000gn/T/ipykernel_61673/2692369937.py:107: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   fig.tight_layout()

# %% [markdown]
# ## Mode-specific wind/grid plot

# %%
import matplotlib.pyplot as plt

if wind_df_results is None or wind_df_results.empty:
    print("Skipping mode-specific analysis.")
else:
    wind_df_results["datetime"] = pd.to_datetime(wind_df_results["datetime"])
    
    # Add rep day identifier if available
    if "REP_SEASON" in wind_df_results.columns and "REP_KIND" in wind_df_results.columns:
        wind_df_results["rep_day"] = (wind_df_results["REP_SEASON"] + " - " + 
                                      wind_df_results["REP_KIND"].str.upper())
    else:
        wind_df_results["rep_day"] = wind_df_results["datetime"].dt.date
    
    # Blended mode analysis: wind fraction distribution
    if WIND_LCA_MODE in ("blended", "both"):
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
        
        blended_df = wind_df_results[wind_df_results["lca_mode"] == "blended"]
        if not blended_df.empty:
            # Left: Wind fraction vs GWP100 per representative day
            for rep_day in sorted(blended_df["rep_day"].unique()):
                day_df = blended_df[blended_df["rep_day"] == rep_day]
                ax1.scatter(day_df["wind_fraction"], day_df["gwp100_kgco2e_per_kg_h2"],
                           label=rep_day, alpha=0.6, s=30)
            ax1.set_xlabel("Wind fraction of electrolyser input", fontsize=11)
            ax1.set_ylabel("GWP100 (kg CO2e/kg H2)", fontsize=11)
            ax1.set_title("Blended mode: wind fraction vs. GWP100 (by rep. day)", fontsize=12)
            ax1.legend(fontsize=8, loc="best", ncol=2)
            ax1.grid(True, alpha=0.3)
            
            # Right: Mean GWP100 per representative day
            blended_summary = blended_df.groupby("rep_day")["gwp100_kgco2e_per_kg_h2"].mean().sort_values()
            ax2.barh(range(len(blended_summary)), blended_summary.values, color="steelblue", alpha=0.7)
            ax2.set_yticks(range(len(blended_summary)))
            ax2.set_yticklabels(blended_summary.index, fontsize=9)
            ax2.set_xlabel("Mean GWP100 (kg CO2e/kg H2)", fontsize=11)
            ax2.set_title("Blended mode: mean GWP100 per representative day", fontsize=12)
            ax2.grid(True, alpha=0.3, axis="x")
            
            fig.tight_layout()
            plt.show()
    
    # Switching mode analysis: electricity source distribution
    if WIND_LCA_MODE in ("switching", "both"):
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
        
        switching_df = wind_df_results[wind_df_results["lca_mode"] == "switching"]
        if not switching_df.empty:
            # Left: Wind vs grid usage by representative day
            src_by_day = switching_df.groupby(["rep_day", "electricity_source"]).size().unstack(fill_value=0)
            src_by_day_pct = src_by_day.div(src_by_day.sum(axis=1), axis=0) * 100
            src_by_day_pct.plot(kind="barh", stacked=True, ax=ax1, 
                               color=["#d62728", "#2ca02c"], alpha=0.8)
            ax1.set_xlabel("Percentage of slices (%)", fontsize=11)
            ax1.set_ylabel("Representative day", fontsize=11)
            ax1.set_title("Switching mode: wind vs. grid usage by rep. day", fontsize=12)
            ax1.legend(title="Electricity source", fontsize=9)
            ax1.grid(True, alpha=0.3, axis="x")
            
            # Right: Mean GWP100 per representative day
            switching_summary = switching_df.groupby("rep_day")["gwp100_kgco2e_per_kg_h2"].mean().sort_values()
            ax2.barh(range(len(switching_summary)), switching_summary.values, color="coral", alpha=0.7)
            ax2.set_yticks(range(len(switching_summary)))
            ax2.set_yticklabels(switching_summary.index, fontsize=9)
            ax2.set_xlabel("Mean GWP100 (kg CO2e/kg H2)", fontsize=11)
            ax2.set_title("Switching mode: mean GWP100 per representative day", fontsize=12)
            ax2.grid(True, alpha=0.3, axis="x")
            
            fig.tight_layout()
            plt.show()

# %% [markdown]
# ## Combined summary table

# %%
import pandas as pd

rows = []

# Grid results summary
if grid_df_results is not None and not grid_df_results.empty:
    metadata_cols = {"carbon_intensity", "custom_electricity_score",
                     "custom_electricity_input_kwh_per_kwh", "REP_SEASON", "REP_KIND"}
    
    if "REP_SEASON" in grid_df_results.columns and "REP_KIND" in grid_df_results.columns:
        # Break down by representative day
        for (season, kind), group in grid_df_results.groupby(["REP_SEASON", "REP_KIND"]):
            for tech in [c for c in group.columns if c not in metadata_cols]:
                s = group[tech]
                rows.append({
                    "source": "custom_grid", "rep_day": f"{season} - {kind.upper()}",
                    "technology": tech,
                    "n_slices": int(s.notna().sum()),
                    "mean_gwp100": s.mean(), "min_gwp100": s.min(), "max_gwp100": s.max(),
                })
    else:
        # No rep day info, just aggregate
        for tech in [c for c in grid_df_results.columns if c not in metadata_cols]:
            s = grid_df_results[tech]
            rows.append({
                "source": "custom_grid", "rep_day": "all",
                "technology": tech,
                "n_slices": int(s.notna().sum()),
                "mean_gwp100": s.mean(), "min_gwp100": s.min(), "max_gwp100": s.max(),
            })

# Wind/grid results summary
if wind_df_results is not None and not wind_df_results.empty:
    wind_df_results["datetime"] = pd.to_datetime(wind_df_results["datetime"])
    
    if "REP_SEASON" in wind_df_results.columns and "REP_KIND" in wind_df_results.columns:
        # Break down by representative day and LCA mode
        for (season, kind, mode, tech), group in wind_df_results.groupby(
            ["REP_SEASON", "REP_KIND", "lca_mode", "electrolyser_tech"]
        ):
            s = group["gwp100_kgco2e_per_kg_h2"]
            rows.append({
                "source": "wind_grid", "rep_day": f"{season} - {kind.upper()}",
                "lca_mode": mode, "technology": tech,
                "n_slices": int(s.notna().sum()),
                "mean_gwp100": s.mean(), "min_gwp100": s.min(), "max_gwp100": s.max(),
            })
    else:
        # No rep day info
        for (mode, tech), group in wind_df_results.groupby(["lca_mode", "electrolyser_tech"]):
            s = group["gwp100_kgco2e_per_kg_h2"]
            rows.append({
                "source": "wind_grid", "rep_day": "all",
                "lca_mode": mode, "technology": tech,
                "n_slices": int(s.notna().sum()),
                "mean_gwp100": s.mean(), "min_gwp100": s.min(), "max_gwp100": s.max(),
            })

if rows:
    summary = pd.DataFrame(rows)
    # Set appropriate multi-index based on available columns
    if "lca_mode" in summary.columns:
        summary = summary.set_index(["source", "rep_day", "lca_mode", "technology"])
    else:
        summary = summary.set_index(["source", "rep_day", "technology"])
    
    # Sort for better readability
    summary = summary.sort_index()
    display(summary)
else:
    print("No results to summarise. Run the building-block notebooks first.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 19
#      15                 rows.append({
#      16                     "source": "custom_grid", "rep_day": f"{season} - {kind.upper()}",
#      17                     "technology": tech,
#      18                     "n_slices": int(s.notna().sum()),
# ---> 19                     "mean_gwp100": s.mean(), "min_gwp100": s.min(), "max_gwp100": s.max(),
#      20                 })
#      21     else:
#      22         # No rep day info, just aggregate
#
# File /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/pandas/core/series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
#    8072     Return the mean of the values over the requested axis.
#    8073
#    (...)   8111     2.0
#    8112     """
# -> 8113     return NDFrame.mean(
#    8114         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115     )
#
# File /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/pandas/core/generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11827         skipna: bool = True,
#   11828         numeric_only: bool = False,
#   11829         **kwargs,
#   11830     ) -> Series | float:
# > 11831         return self._stat_function(
#   11832             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833         )
#
# File /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/pandas/core/generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781         nv.validate_func(name, (), kwargs)
#   11782
#   11783         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11784
# > 11785         return self._reduce(
#   11786             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787         )
#
# File /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/pandas/core/series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File /opt/miniconda3/envs/brightway/lib/python3.11/site-packages/pandas/core/arrays/string_.py:969, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     966         return self._from_sequence([result], dtype=self.dtype)
#     967     return result
# --> 969 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype
